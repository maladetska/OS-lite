# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # EXPERIMENT 1 #

# %% [markdown]
# ## CPU 1 ##

# %%
seq1 = [
    3.4,
    6.704,
    9.956,
    13.796,
    16.514,
    19.596,
    22.288,
    26.936,
    28.682,
    41.854,
    37.086,
    38.858,
    44.204,
    56.362,
    51.786,
    54.31,
    56.152,
    60.146,
    62.532,
    67.602
]

# %%
parallel1 = [
    4.708,
    7.784,
    10.388,
    13.958,
    18.106,
    20.722,
    23.972,
    28.924,
    31.216,
    35.068,
    37.58,
    39.752,
    41.656,
    45.06,
    46.598,
    50.532,
    54.46,
    61.892,
    69.29,
    70.076
]

# %% [markdown]
# ## CPU 2 ##

# %%
seq2 = [
    3.406,
    6.39,
    10.038,
    13.584,
    15.524,
    18.964,
    21.376,
    24.622,
    27.966,
    31.218,
    33.948,
    52.518,
    39.928,
    44.64,
    45.946,
    50.386,
    54.46,
    57.216,
    62.776,
    65.606
]

# %%
parallel2 = [
    3.716,
    4.39,
    7.258,
    7.202,
    9.174,
    10.932,
    12.19,
    13.584,
    15.074,
    18.432,
    28.95,
    20.262,
    21.9,
    24.26,
    25.454,
    27.262,
    28.704,
    31.248,
    31.048,
    31.558
]

# %% [markdown]
# # GRAPHS #

# %%
fig, ax = plt.subplots()
ax.plot(seq1, label='SEQ.1')
ax.plot(parallel1, label='PARALLEL.1')
ax.legend()

# %%
fig, ax = plt.subplots()
ax.plot(seq2, label='SEQ.2')
ax.plot(parallel2, label='PARALLEL.2')
ax.legend()

# %%
fig, ax = plt.subplots()
ax.plot(seq1, label='SEQ.1')
ax.plot(seq2, label='SEQ.2')
ax.legend()

# %%
fig, ax = plt.subplots()
ax.plot(parallel1, label='PARALLEL.1')
ax.plot(parallel2, label='PARALLEL.2')
ax.legend()

# %% [markdown]
# # EXPERIMENT 2 #

# %% [markdown]
# ## CPU 1 ##

# %%
seq1 = [
    1.694,
    2.846,
    4.992,
    5.556,
    6.74,
    8.284,
    10.8,
    10.416,
    12.338,
    13.866,
    14.054,
    15.25,
    28.154,
    17.724,
    19.014,
    26.996,
    25.824,
    26.028,
    27.81,
    27.648
]

# %%
parallel1 = [
    2.22,
    4.41,
    5.106,
    6.618,
    9.628,
    8.952,
    12.102,
    14.224,
    13.486,
    15.84,
    15.978,
    17.644,
    20.656,
    24.238,
    24.128,
    27.21,
    28.856,
    28.166,
    30.952,
    45.974
]

# %% [markdown]
# ## CPU 2 ##

# %%
seq2 = [
    1.68,
    3.218,
    4.88,
    7.108,
    6.948,
    8.976,
    9.326,
    10.374,
    12.708,
    13.95,
    15.634,
    16.546,
    18.746,
    22.796,
    22.794,
    24.742,
    26.932,
    27.364,
    29.596,
    32.092
]

# %%
parallel2 = [
    1.748,
    2.166,
    3.34,
    4.25,
    3.93,
    4.612,
    6.464,
    6.53,
    7.378,
    8.246,
    9.122,
    9.954,
    10.79,
    11.62,
    12.864,
    13.156,
    13.838,
    14.972,
    14.238,
    14.95
]

# %% [markdown]
# # GRAPHS #

# %%
fig, ax = plt.subplots()
ax.plot(seq1, label='SEQ.1')
ax.plot(parallel1, label='PARALLEL.1')
ax.legend()

# %%
fig, ax = plt.subplots()
ax.plot(seq2, label='SEQ.2')
ax.plot(parallel2, label='PARALLEL.2')
ax.legend()

# %%
fig, ax = plt.subplots()
ax.plot(seq1, label='SEQ.1')
ax.plot(seq2, label='SEQ.2')
ax.legend()

# %%
fig, ax = plt.subplots()
ax.plot(parallel1, label='PARALLEL.1')
ax.plot(parallel2, label='PARALLEL.2')
ax.legend()
